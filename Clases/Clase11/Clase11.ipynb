# %% [markdown]
# ### Dato curioso del día
#
# - https://twitter.com/dansinker/status/1321227774246486022
#
# - https://www.nature.com/articles/s41746-018-0045-1

# %% [markdown]
# <center><img src='img/init.png' style='height:300px; float: center; margin: 0px 15px 15px 0px'></center>
#
# ### Modelado de temas
# #### NLP - Analítica Estratégica de Datos
# <br><b>Fundación Universitaria Konrad Lorenz</b>
# <br>Docente: Viviana Márquez [vivianam.penama@konradlorenz.edu.co](mailto:vivianama.penam@konradlorenz.edu.co)
# <br>Clase #11: 🎃Octubre 31, 2020

# %% [markdown]
# # Retroalimentación taller 7 & 8

# %% [markdown]
# ### 🚵‍♀️ Entramos en la recta final...
# <img src='img/pipeline.png'>

# %% [markdown]
# ### 🚵‍♀️ Entramos en la recta final...
# <img src='img/pipeline_class2.png'>

# %% [markdown]
# ### 🚵‍♀️ Entramos en la recta final...
# <img src='img/pipeline_class.png'>

# %% [markdown]
# ### 🚀 Hoy veremos...
#
# - Visualizaciones para proyectos de NLP 🚵‍♀️
#
# <img src='https://cdn3.whatculture.com/images/2017/06/f42c655b8c1751ba-600x338.gif'>

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# <br>
# <img src='img/pic2.png' style='height:500px; float: left; margin: 15px 15px 15px 15px'>
#
# - Parte esencial de un profesional en datos
# - Estamos un mundo lleno de datos
# - Queremos ganar conocimiento (ENTENDER)
# - Queremos hacer impacto (COMUNICAR)

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para ENTENDER nuestros datos
#
# <br>
# <img src='img/ss1.png' style='height:500px'>

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para ENTENDER nuestros datos
#
# <br>
# <img src='img/ss2.png' style='height:500px'>

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para COMUNICAR nuestros datos
#
# <br>
# <img src='img/ss3.png' style='height:500px'>

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para COMUNICAR nuestros datos
#
# <br>
# <img src='img/ss4b.png' style='height:500px'>

# %% [markdown]
# ### ⚙️ Herramientas más populares en el mercado para hacer visualizaciones
#
# <br>
# <img src='img/herramientas2.png' style='height:500px'>

# %% [markdown]
# ### ⚙️ Herramientas más populares en el mercado para hacer visualizaciones
#
# <br>
# <img src='img/info.png' style='height:500px'>

# %% [markdown]
# ### ⚙️ Herramientas más populares en el mercado para hacer visualizaciones
#
# <br><br>
# <img src='img/python.jpg' style='height:300px; float: left; margin: 15px 15px 15px 15px'>
#
# - Matplotlib
# - Seaborn
# - Plotly
# - Bokeh
# - Altair
# - Geoplotlib

# %% [markdown]
# # 😉 Tips generales para las visualizaciones
# Source: HubSpot + Visage

# %% [markdown]
# <img src='img/tip1a.png'>

# %% [markdown]
# <img src='img/tip2.png'>

# %% [markdown]
# <img src='img/tip4.png'>

# %% [markdown]
# <img src='img/tip5.png'>

# %% [markdown]
# # 😉 Tips generales para las visualizaciones
#
# - Piensa en la audiencia:
#     - ¿Cómo van a crear tus datos objetivos realizables?
#     - ¿Su público tiene el software necesario?
#
# - Menos es más
#     - En un mundo lleno de datos, queremos ENTENDER y COMUNICAR

# %% [markdown]
# ### 🙋‍♀️ ¿Qué se dicen mis estudiantes?
#
# <br>
# <center><img src='img/estudiantes.jpeg' style='height:250px; float: center; margin: 0px 15px 15px 0px'></center>
#
# <table>
#  <tr>
#     <td><b style="font-size:35px">Herramientas</b></td>
#     <td><b style="font-size:35px">Gráficas</b></td>
#  </tr>
#  <tr>
#     <td>Jupyter Notebook</td>
#     <td>Mapas</td>
#  </tr>
# <tr>
#     <td>Plotly & Dash</td>
#     <td>Mapas de calor</td>
#  </tr>
# <tr>
#     <td>Flask</td>
#     <td>Barras</td>
#  </tr>
# <tr>
#     <td>Tableau</td>
#     <td>Nube de palabras</td>
#  </tr>
# <tr>
#     <td>PowerBI</td>
#     <td>Series de tiempo</td>
#  </tr>
#     <tr>
#         <td>Data Studio</td>
#     <td></td>
#  </tr>
# </table>

# %% [markdown]
# ### 🙋‍♀️ ¿Qué se dicen mis estudiantes?
#
# <br>
# <center><img src='img/estudiantes.jpeg' style='height:250px; float: center; margin: 0px 15px 15px 0px'></center>
#
# <table>
#  <tr>
#     <td><b style="font-size:35px">Herramientas</b></td>
#     <td><b style="font-size:35px">Gráficas</b></td>
#  </tr>
#  <tr>
#     <td>✅ Jupyter Notebook</td>
#     <td>✅ Mapas</td>
#  </tr>
# <tr>
#     <td>✅ Plotly ❌ Dash</td>
#     <td>✅ Mapas de calor</td>
#  </tr>
# <tr>
#     <td>❌ Flask</td>
#     <td>✅ Barras</td>
#  </tr>
# <tr>
#     <td>✅ Tableau</td>
#     <td>✅ Nube de palabras</td>
#  </tr>
# <tr>
#     <td>❌ PowerBI</td>
#     <td>✅ Series de tiempo</td>
#  </tr>
#     <tr>
#         <td>❌ <a href='https://datastudio.google.com/u/0/navigation/reporting'>Data Studio</a></td>
#     <td></td>
#  </tr>
# </table>

# %% [markdown]
# # 1. Jupyter Notebook & GitHub Pages
#
# - Jupyter Notebook te da la posibilidad de crear presentaciones con el plugging RISE
#     - `pip install RISE`
#     - `jupyter-nbextension install rise --py --sys-prefix`
#     - `jupyter nbextension enable rise --py --sys-prefix`
# <br><br>
# - GitHub pages te da la opción de publicar presentaciones, páginas web, etc.
#     - Instrucciones para subir presentaciones [aquí](https://medium.com/@alejatorresm/presentaciones-usando-jupyter-notebook-6cb20434fbe9) --- Ejemplo [aquí](https://alejandratm.github.io/Jupyter-Slides-Hola-Mundo/Presentacion-HW/Hello-litle-World.slides.html#/)
#     - Ejemplo página web [aquí](http://vivianamarquez.com/) --- Plantilla [aquí](https://github.com/daattali/beautiful-jekyll)
#     <br><br>
# - Visualizador de Notebooks `https://nbviewer.jupyter.org/github/` --- Ejemplo [(1)](vivianamarquez/NLP_Analitica_Estategica_Datos/blob/master/Clases/Clase10/Clase10.ipynb) [(2)](https://nbviewer.jupyter.org/github/vivianamarquez/NLP_Analitica_Estategica_Datos/blob/master/Clases/Clase10/Clase10.ipynb)

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 1. Instalar RISE
# <br><br>
# <center>
#     <img src='img/rise1.png' style='width:1300px; float: center; margin: 0px 15px 15px 0px'>
#     <img src='img/rise2.png' style='width:1300px; float: center; margin: 0px 15px 15px 0px'>
#     <img src='img/rise3.png' style='width:1300px; float: center; margin: 0px 15px 15px 0px'>
# </center>

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 2. Botón de presentación debe aparecer
# <br><br>
# <center>
#     <img src='img/rise4.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>
#
# 2. Seleccionar Markdown
# <br><br>
# <center>
#     <img src='img/rise5.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 4. Modo presentación
# <br><br>
# <center>
#     <img src='img/rise6.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
#
#     <img src='img/rise7.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 5. Exportar
# <br><br>
# <center>
#     <img src='img/rise8.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>
#
# 6. Los Jupyter Notebooks pueden ser usados para otros lenguajes de programación

# %% [markdown]
# #### Carguemos los datos con los que vamos a trabajar

# %%
import pandas as pd

data = pd.read_csv('archivos/hween_clean.csv')
data.head()
# Out:
#                                                texto                fecha  \
# 0  ¿Desparchado porque mañana no podrás salir a p...  2020-10-31 00:16:27
# 1  Participa en nuestro concurso de disfraces y l...  2020-10-31 00:15:34
# 2  MEGA-ESPECIAL Halloween 🎃 (Parte 53). Yo veo u...  2020-10-31 00:13:59
# 3  Un mensaje especial para los padres de familia...  2020-10-31 00:11:46
# 4                        Luna azul con halloween 🤪👻🤔  2020-10-31 00:10:04
#
#    ciudad  departamento       lat        lon
# 0  Bogotá  Cundinamarca  4.649178 -74.062827
# 1  Bogotá  Cundinamarca  4.649178 -74.062827
# 2  Bogotá  Cundinamarca  4.649178 -74.062827
# 3  Bogotá  Cundinamarca  4.649178 -74.062827
# 4  Bogotá  Cundinamarca  4.649178 -74.062827

# %% [markdown]
# # 2. Nube de palabras
#
# `pip install wordcloud`

# %%
import numpy as np

from wordcloud import WordCloud
from wordcloud import ImageColorGenerator

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import matplotlib.pyplot as plt
import PIL.Image
from IPython.display import display

# %%
palabras = data.texto.str.cat(sep=" ")
wordcloud = WordCloud().generate(palabras)

plt.imshow(wordcloud)
plt.show()

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python
palabras = data.texto.str.cat(sep=' ')

wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='gist_heat',
                     stopwords=stopwords).generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
calabaza = PIL.Image.open("img/calabaza2.png")
display(calabaza)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1574x1420 at 0x7F912E274F90>

# %%
mask = np.array(calabaza)
mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8)

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python
palabras = data.texto.str.cat(sep=' ')

wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='copper_r',
                     stopwords=stopwords,
                     mask=mask, contour_width=0.5, contour_color='orange').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

wordcloud.to_file("calabaza.png")

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # 3. Tableau
#
# Link de descarga: https://public.tableau.com/en-us/s/download
#
# - Programa para crear tableros (dashboards) interactivos
# - Tiene varios productos:
#     - Tableau Desktop (Profesional)
#     - Tableau Server
#     - Tableau Prep (flujo de datos)
#     - Tableau Public (versión gratis) [Link](https://public.tableau.com/profile/viviana.m.rquez#!/?newProfile=&activeTab=0)
#
# - Se puede conectar Python y R a Tableau [Link1](https://vivianamarquez.medium.com/python-tableau-desktop-101-b1281d9f7404) [Link2](https://vivianamarquez.medium.com/tableau-prep-python-101-c6a2b5292233)

# %% [markdown]
# #### Gráficos que vamos a hacer:
# - Nube de palabras
# - Mapa de árbol
# - Mapa

# %% [markdown]
# #### Vamos a preparar los datos

# %%
# nube de palabras & mapa de árbol
ciudad1 = 'Barranquilla'
ciudad2 = 'Medellín'

data1 = data[data.ciudad==ciudad1]
data2 = data[data.ciudad==ciudad2]

palabras1 = data1.texto.str.cat(sep=" ")
palabras2 = data2.texto.str.cat(sep=" ")

wordcloud1 = WordCloud(stopwords = stopwords).generate(palabras1).words_
wordcloud2 = WordCloud(stopwords = stopwords).generate(palabras2).words_

temp1 = pd.DataFrame.from_dict(wordcloud1, orient='index').reset_index()
temp1.columns = ['palabra', 'cnt']
temp1['ciudad'] = ciudad1

temp2 = pd.DataFrame.from_dict(wordcloud2, orient='index').reset_index()
temp2.columns = ['palabra', 'cnt']
temp2['ciudad'] = ciudad2

data_nube = pd.concat([temp1, temp2])

data_nube.to_csv('nube.csv', index=False)

# %%
# mapa
data['contador_palabras'] = data.texto.apply(lambda valor: len(valor.split()))
data[['ciudad', 'lat', 'lon', 'contador_palabras']].to_csv("mapa.csv")

# %% [markdown]
# # Resultado: https://public.tableau.com/profile/viviana.m.rquez#!/vizhome/HalloweenNLP/Dashboard1?publish=yes

# %% [markdown]
# # 4. La trifecta: Plotly, Dash y Flask
#
# - **Plotly**: Herramienta de visualización interactiva. Funciona con Python, R, Julia, etc.
# [Recurso](https://plotly.com/python/plotly-fundamentals/)
#
# - **Dash**: Entorno de trabajo para construir aplicaciones web (usa Flask y Plotly)
# [Rescurso](https://www.datacamp.com/community/tutorials/learn-build-dash-python). [Ejemplo](https://msds2019.herokuapp.com/)
#
# - **Flask**: Entorno de trabajo para construir aplicaciones web para Python
# [Recurso](https://flask.palletsprojects.com/en/1.1.x/tutorial/)
#
# `pip install plotly==4.12.0`

# %% [markdown]
# # ¡Tiempo de taller!
#
# <center>
# <img src='img/Taller.gif'>
#
# **Fecha de entrega:** Noviembre 7, 2020. (Antes del inicio de la próxima clase)

# %% [markdown]
# # Evaluación!!! Me lo prometieron!
# # Nos vemos a las 10:30 a.m. para GitHub y Nube de Palabras
#
# <img src='https://em.wattpad.?s=fit&w=720&h=720'>
#
# # Evaluación docente
# 13 de octubre al 7 de noviembre
#
# # [http://virtual2.konradlorenz.edu.co/login/index.php](http://virtual2.konradlorenz.edu.co/login/index.php)
#
# Cualquier duda o requerimiento puede ser remitido al correo [evaluacion.docente@konradlorenz.edu.co](mailto:evaluacion.docente@konradlorenz.edu.co)

# %% [markdown]
# <center>
#     <img src='img/fin.gif'>
#
# ### Próxima clase: NLP y Redes Sociales
