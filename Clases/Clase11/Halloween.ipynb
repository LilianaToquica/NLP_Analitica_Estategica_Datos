# %%
import re
import json
import random
import pandas as pd

import tweepy
from tweepy import Stream
from tweepy.streaming import StreamListener

# %%
# Load Keys
keys = pd.read_csv("archivos/keys_royardo.csv",header=None)
keys = dict(zip(keys[0],keys[1]))

# Authenticate through the API
auth = tweepy.OAuthHandler(keys['api_key'], keys['api_secret_key'])
auth.set_access_token(keys['access_token'], keys['access_token_secret'])
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
ciudades = pd.read_csv('archivos/co_small.csv')
ciudades
# Out:
#                      city        lat        lng   country iso2  \
# 0                  Bogotá   4.649178 -74.062827  Colombia   CO
# 1                Medellín   6.251840 -75.563591  Colombia   CO
# 2                    Cali   3.437222 -76.522500  Colombia   CO
# 3            Barranquilla  10.963889 -74.796389  Colombia   CO
# 4             Bucaramanga   7.125393 -73.119804  Colombia   CO
# 5               Cartagena  10.399722 -75.514444  Colombia   CO
# 6                  Cúcuta   7.893907 -72.507821  Colombia   CO
# 7                 Pereira   4.813333 -75.696111  Colombia   CO
# 8             Santa Marta  11.240791 -74.199040  Colombia   CO
# 9                  Ibagué   4.438889 -75.232222  Colombia   CO
# 10                  Pasto   1.213611 -77.281111  Colombia   CO
# 11              Manizales   5.068890 -75.517383  Colombia   CO
# 12          Villavicencio   4.142002 -73.626645  Colombia   CO
# 13                  Neiva   2.927299 -75.281885  Colombia   CO
# 14                Armenia   4.533889 -75.681111  Colombia   CO
# 15             Valledupar  10.463140 -73.253224  Colombia   CO
# 16               Montería   8.747984 -75.881428  Colombia   CO
# 17              Sincelejo   9.304722 -75.397778  Colombia   CO
# 18                Popayán   2.444444 -76.613889  Colombia   CO
# 19                  Tunja   5.535278 -73.367778  Colombia   CO
# 20               Ríohacha  11.544444 -72.907222  Colombia   CO
# 21              Florencia   1.614382 -75.606229  Colombia   CO
# 22                 Quibdó   5.694722 -76.661111  Colombia   CO
# 23                 Arauca   7.084512 -70.755366  Colombia   CO
# 24                  Yopal   5.337752 -72.395859  Colombia   CO
# 25                Leticia  -4.215278 -69.940556  Colombia   CO
# 26             San Andrés  12.584722 -81.700556  Colombia   CO
# 27  San José del Guaviare   2.572858 -72.645914  Colombia   CO
# 28                  Mocoa   1.149327 -76.646610  Colombia   CO
# 29         Puerto Carreño   6.189031 -67.485879  Colombia   CO
# 30                   Mitú   1.257778 -70.234722  Colombia   CO
# 31                Inírida   3.865278 -67.923889  Colombia   CO
#
#                        admin  capital  population  population_proper
# 0                     Bogotá  primary   7772000.0          6333661.0
# 1                  Antioquia    admin   3297000.0          1999979.0
# 2            Valle del Cauca    admin   2254000.0          2178836.0
# 3                  Atlántico    admin   1798000.0          1244491.0
# 4                  Santander    admin   1009000.0           571820.0
# 5                    Bolívar    admin    887000.0           887000.0
# 6         Norte de Santander    admin    722146.0           721398.0
# 7                  Risaralda    admin    568750.0           440118.0
# 8                  Magdalena    admin    431781.0           402641.0
# 9                     Tolima    admin    421685.0           408627.0
# 10                    Nariño    admin    382236.0           360041.0
# 11                    Caldas    admin    375848.0           357814.0
# 12                      Meta    admin    374763.0           321717.0
# 13                     Huila    admin    352855.0           284277.0
# 14                   Quindío    admin    315328.0           314267.0
# 15                     Cesar    admin    308237.0           287018.0
# 16                   Córdoba    admin    275198.0           272420.0
# 17                     Sucre    admin    261187.0           218388.0
# 18                     Cauca    admin    258750.0           258750.0
# 19                    Boyacá    admin    161412.0           117479.0
# 20                La Guajira    admin    133186.0            92431.0
# 21                   Caquetá    admin    130337.0            44861.0
# 22                     Chocó    admin     92780.0            75104.0
# 23                    Arauca    admin     69264.0            23797.0
# 24                  Casanare    admin     61029.0            61029.0
# 25                  Amazonas    admin     59575.0            32450.0
# 26  San Andrés y Providencia    admin     58257.0            58257.0
# 27                  Guaviare    admin     22136.0            21214.0
# 28                  Putumayo    admin     22035.0            22035.0
# 29                   Vichada    admin     10216.0             5861.0
# 30                    Vaupés    admin      5917.0             5917.0
# 31                   Guainía    admin         NaN                NaN

# %% [markdown]
# # Per city

# %%
all_tweets = []

for ciudad in ciudades.iterrows():
    c = ciudad[1]
    gc = f"{c.lat},{c.lng},45mi"

    tweets = tweepy.Cursor(api.search, 
                       q=['halloween -RT'], 
                       lang="es",
                       since='2020-10-24', 
                       geocode=gc,
                       tweet_mode='extended',
                       include_rts=False).items(100)
    
    
    t = []
    for tweet in tweets:
        t.append([
            tweet.full_text,
            tweet.created_at,
            c.city,
            tweet.user.location,
            tweet.place,
            tweet.coordinates,
            f"https://twitter.com/i/web/status/{tweet.id}"])
        
    all_tweets.extend(t)
    print(c.city)
# Out:
# Bogotá
# Medellín
# Cali
# Barranquilla
# Bucaramanga
# Cartagena
# Cúcuta
# Pereira
# Santa Marta
# Ibagué
# Pasto
# Manizales
# Villavicencio
# Neiva
# Armenia
# Valledupar
# Montería
# Sincelejo
# Popayán
# Tunja
# Ríohacha
# Florencia
# Quibdó
# Arauca
# Yopal
# Leticia
# San Andrés
# San José del Guaviare
# Mocoa
# Puerto Carreño
# Mitú
# Inírida

# %%
data = pd.DataFrame(all_tweets)
data.columns = ['tweet', 'date', 'city', 'user_location', 'place', 'coordinates', 'link']
data
# Out:
#                                                   tweet                date  \
# 0     ¿Desparchado porque mañana no podrás salir a p... 2020-10-31 00:16:27
# 1     Participa en nuestro concurso de disfraces y l... 2020-10-31 00:15:34
# 2     MEGA-ESPECIAL Halloween 🎃 (Parte 53).\n\nYo ve... 2020-10-31 00:13:59
# 3     Un mensaje especial para los padres de familia... 2020-10-31 00:11:46
# 4     Luna azul con halloween 🤪👻🤔 https://t.co/gjQhV... 2020-10-31 00:10:04
# ...                                                 ...                 ...
# 2229  #lacurasoyyo cuando celebro Halloween con mi f... 2020-10-26 20:05:38
# 2230  Este halloween #LaCuraSoyYo 👻🎃\n.\n.\n.\n@gobn... 2020-10-26 17:30:07
# 2231  Decora su casa para Halloween con un crimen y ... 2020-10-30 09:31:58
# 2232  Disfruta del mejor #horror en casa🎃\n\n #Infec... 2020-10-26 18:09:31
# 2233  ¿Dulce o truco? la leyenda sobre esta frase de... 2020-10-26 09:31:57
#
#                 city             user_location  \
# 0             Bogotá          Bogotá, Colombia
# 1             Bogotá                    Bogota
# 2             Bogotá          Bogotá, Colombia
# 3             Bogotá         Bogotá - Colombia
# 4             Bogotá           bogota,Colombia
# ...              ...                       ...
# 2229           Mocoa         San Juan de Pasto
# 2230           Mocoa         San Juan de Pasto
# 2231  Puerto Carreño  Isla Margarita Venezuela
# 2232  Puerto Carreño        Caracas, Venezuela
# 2233  Puerto Carreño  Isla Margarita Venezuela
#
#                                                   place coordinates  \
# 0                                                  None        None
# 1                                                  None        None
# 2                                                  None        None
# 3                                                  None        None
# 4                                                  None        None
# ...                                                 ...         ...
# 2229                                               None        None
# 2230                                               None        None
# 2231                                               None        None
# 2232  Place(_api=<tweepy.api.API object at 0x7ff7792...        None
# 2233                                               None        None
#
#                                                    link
# 0     https://twitter.com/i/web/status/1322331566929...
# 1     https://twitter.com/i/web/status/1322331341812...
# 2     https://twitter.com/i/web/status/1322330942871...
# 3     https://twitter.com/i/web/status/1322330385573...
# 4     https://twitter.com/i/web/status/1322329960250...
# ...                                                 ...
# 2229  https://twitter.com/i/web/status/1320818893242...
# 2230  https://twitter.com/i/web/status/1320779757378...
# 2231  https://twitter.com/i/web/status/1322108977778...
# 2232  https://twitter.com/i/web/status/1320789670872...
# 2233  https://twitter.com/i/web/status/1320659421190...
#
# [2234 rows x 7 columns]

# %%
data[~data.coordinates.isna()].loc[7]['city']
# Out:
# 'Bogotá'

# %%
data[~data.coordinates.isna()].loc[7]['coordinates']['coordinates']
# Out:
# [-74.0794, 4.5997]

# %%
data.city.value_counts()
# Out:
# Cúcuta                   100
# Tunja                    100
# Bogotá                   100
# Ibagué                   100
# Neiva                    100
# Montería                 100
# Cartagena                100
# Medellín                 100
# Valledupar               100
# Pereira                  100
# Ríohacha                 100
# Santa Marta              100
# Barranquilla             100
# Cali                     100
# Bucaramanga              100
# Sincelejo                100
# Manizales                100
# Villavicencio            100
# Armenia                  100
# Popayán                   94
# Pasto                     55
# Yopal                     48
# Arauca                    41
# Florencia                 38
# Mocoa                     28
# San José del Guaviare     14
# Quibdó                     6
# Leticia                    4
# San Andrés                 3
# Puerto Carreño             3
# Name: city, dtype: int64

# %%
data.shape
# Out:
# (2234, 7)

# %%
data.date.min()
# Out:
# Timestamp('2020-10-24 02:15:18')

# %%
data.to_csv("halloween.csv", index=False)
