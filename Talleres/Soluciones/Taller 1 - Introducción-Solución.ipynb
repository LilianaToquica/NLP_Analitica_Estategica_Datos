# %% [markdown]
# # Cargar datos de Google Docs
#
# https://docs.google.com/spreadsheets/d/15CGVDsx96eJOivSEdcatWaCOmBO465soHz_gQ_q7LhA/edit?usp=sharing

# %%
url = "https://docs.google.com/spreadsheets/d/15CGVDsx96eJOivSEdcatWaCOmBO465soHz_gQ_q7LhA/edit?usp=sharing"

# %% [markdown]
# Ahora debemos modificar la url para poder abrir el archivo en Python. Esto lo hacemos eliminando todo lo que este después de la llave y agregando `gviz/tq?tqx=out:csv`. La llave de un Google Sheets es lo que esta después de `/d/`

# %%
url.rsplit("/",1)[0]
# Out:
# 'https://docs.google.com/spreadsheets/d/15CGVDsx96eJOivSEdcatWaCOmBO465soHz_gQ_q7LhA'

# %%
new_url = url.rsplit("/",1)[0] + "/gviz/tq?tqx=out:csv"
new_url
# Out:
# 'https://docs.google.com/spreadsheets/d/15CGVDsx96eJOivSEdcatWaCOmBO465soHz_gQ_q7LhA/gviz/tq?tqx=out:csv'

# %%
import pandas as pd

data = pd.read_csv(new_url)

# %%
data.head()
# Out:
#    #                 Nombre  \
# 0   1       Viviana Márquez
# 1   2           Jorge Gomez
# 2   3  Ilvar Dario Sanabria
# 3   4          Camilo Rojas
# 4   5            Xiomy Díaz
#
#   ¿Por qué estás estudiando análitica estratégica de datos? Sistema Operativo  \
# 0  Me gustan mucho las matemáticas, la programaci...                   macOSx
# 1        Desarrollo profesional y proyecto personal.              Windows x64
# 2  Muchas de las decisiones se basan en datos y c...              Windows x64
# 3  Trabajo con temas relacionados a gestión de in...              Windows x64
# 4  En mi experiencia en investigación de mercados...              Windows x64
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ...  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...          NaN          NaN          NaN          NaN          NaN
# 2  ...          NaN          NaN          NaN          NaN          NaN
# 3  ...          NaN          NaN          NaN          NaN          NaN
# 4  ...          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 27 columns]

# %%
# Eliminamos columnas vacias

data.dropna(axis=1, inplace=True)

data.head()
# Out:
#    #                 Nombre  \
# 0   1       Viviana Márquez
# 1   2           Jorge Gomez
# 2   3  Ilvar Dario Sanabria
# 3   4          Camilo Rojas
# 4   5            Xiomy Díaz
#
#   ¿Por qué estás estudiando análitica estratégica de datos? Sistema Operativo
# 0  Me gustan mucho las matemáticas, la programaci...                   macOSx
# 1        Desarrollo profesional y proyecto personal.              Windows x64
# 2  Muchas de las decisiones se basan en datos y c...              Windows x64
# 3  Trabajo con temas relacionados a gestión de in...              Windows x64
# 4  En mi experiencia en investigación de mercados...              Windows x64

# %%
# Cambiamos el nombre de la columna porque es muy largo

data.rename(columns={'¿Por qué estás estudiando análitica estratégica de datos?': 'Respuesta'}, inplace=True)

data.head()
# Out:
#    #                 Nombre  \
# 0   1       Viviana Márquez
# 1   2           Jorge Gomez
# 2   3  Ilvar Dario Sanabria
# 3   4          Camilo Rojas
# 4   5            Xiomy Díaz
#
#                                            Respuesta Sistema Operativo
# 0  Me gustan mucho las matemáticas, la programaci...            macOSx
# 1        Desarrollo profesional y proyecto personal.       Windows x64
# 2  Muchas de las decisiones se basan en datos y c...       Windows x64
# 3  Trabajo con temas relacionados a gestión de in...       Windows x64
# 4  En mi experiencia en investigación de mercados...       Windows x64

# %% [markdown]
# # Contar el número de palabras por estudiante
#
# Pista:

# %%
"Hola, ¿Cómo estás?".split()
# Out:
# ['Hola,', '¿Cómo', 'estás?']

# %% [markdown]
# Esto se puede hacer de muchas maneras. Aquí lo voy hacer creando una nueva columna con una función lambda.

# %%
data['Contar'] = data['Respuesta'].apply(lambda fila: len(fila.split()))

# %%
data.head()
# Out:
#    #                 Nombre  \
# 0   1       Viviana Márquez
# 1   2           Jorge Gomez
# 2   3  Ilvar Dario Sanabria
# 3   4          Camilo Rojas
# 4   5            Xiomy Díaz
#
#                                            Respuesta Sistema Operativo  Contar
# 0  Me gustan mucho las matemáticas, la programaci...            macOSx      24
# 1        Desarrollo profesional y proyecto personal.       Windows x64       5
# 2  Muchas de las decisiones se basan en datos y c...       Windows x64      22
# 3  Trabajo con temas relacionados a gestión de in...       Windows x64      27
# 4  En mi experiencia en investigación de mercados...       Windows x64      64

# %% [markdown]
# Para organizar por mayor número de palabras, usamos el siguiente comando:

# %%
data.sort_values(['Contar'], ascending=False).head()
# Out:
#     #                        Nombre  \
# 4    5                   Xiomy Díaz
# 10  11    Arturo Hernández Carvajal
# 19  20  Duberney Agudelo Delgadillo
# 7    8  Norma Yuliana Cala Martinez
# 28  29       Daileny Dorado Delgado
#
#                                             Respuesta Sistema Operativo  \
# 4   En mi experiencia en investigación de mercados...       Windows x64
# 10  Trabajo con altos volúmenes de información est...       Windows x64
# 19  Mi interés en la especialización es tener un c...       Windows x64
# 7   En mi carrera profesional es muy útil y porque...       Windows x64
# 28  Me parece que la tecnología es lo que rige el ...       Windows x64
#
#     Contar
# 4       64
# 10      63
# 19      56
# 7       34
# 28      29

# %% [markdown]
# # Palabra más utilizada
#
# Pista

# %%
" ".join(["hola mundo", "chao mundo"])
# Out:
# 'hola mundo chao mundo'

# %% [markdown]
# Como todo en Python, para resolver este problema hay muchas maneras. Aquí les voy a mostrar una manera:

# %%
data['Respuesta'].values # Lista con cada una de las respuestas

cadena = " ".join(data['Respuesta'].values)

cadena
# Out:
# 'Me gustan mucho las matemáticas, la programación y la comunicación. Pienso que la ciencia de datos es una buena mezcla entre esas tres áreas. Desarrollo profesional y proyecto personal. Muchas de las decisiones se basan en datos y creo que nos aportan mucho tanto en lo personal como en lo profesional Trabajo con temas relacionados a gestión de información y estoy interesado en aprender a utilizar herramientas que faciliten la toma de decisiones en mi lugar de trabajo. En mi experiencia en investigación de mercados y mercadeo empecé a descubrir el mundo de la analítica y me apasiona saber que podemos usar los avances tecnológicos y la gran cantidad de datos que hay, para entender mejor a los clientes y desarrollar proyectos que ayuden a facilitar los procesos en las organizaciones, además es útil en mi trabajo como analista de investigación digital Me gustan mucho los datos y quiero aprenden como aprovecharlos al maximo Me encuentro interesado en aprender diferentes métodos, metodologías, lenguajes y demás para convertirme en un Científico de Datos En mi carrera profesional es muy útil y porque el manejo de la información día a día genera mucho interes y mucho valor en todo. Quiero aprender mucho de herramientas y temas al respecto. Quiero crear productos digitales de alto impacto, que solucionen problemas y sean rentables. Me gusta programar en python Porder aplicar mis conocimientos a mi labor profesional en analitica web , creando modelos de recomendación y personalizacion para las paginas web (contenidos - ecommerce - apps) Trabajo con altos volúmenes de información estructurada y no estructurada con lo que mi interés es generar valor a la compañía y a los sectores de interes usando herramientas de analitica para procesar información de clientes, ventas, procesos de reclamación, quejas, contactos con bots entre otros. Ademas veo que es un complemento interesante con otras áreas de trabajo entre las técnicas y humanas.  Implementar métodos de estudio de machine learning a las ciencias sociales Estamos en contacto permanente con los datos y me gusta saber cómo hay una interacción entre ellos y cómo pueden tomarse decisiones basados en estos. Aprender y sacar el mejor provecho a los conocimientos adquiridos Quiero aprender a sacarle provecho a los datos y darles un valor en mi vida profesional y personal Aprender nuevas herramientas y saber como analizar los datos para la toma de decisiones Generar nuevos conocimientos en herramientas de analitica que me aporten para el analisis de la información y en toma de decisiones . Por la gran cantidad de datos que se maneja en mi ámbito laboral, y por el reto personal que para mi refleja manejar esos datos El mundo actual cuenta con grandes volumenes de datos, pero ahora es tiempo de analizar y comprender las necesidades de cada sector. Mi interés en la especialización es tener un conocimiento más amplio, enfocado y profesional para la manipulación de datos, abarcando desde la recolección, procesamiento, análisis e interpretación para el usuario final cuyo un objetivo fundamental es generar valor agregado en mis reportes para una óptima toma de decisiones que beneficien cualquier plan estratégico en las empresas Por complemento profesional, porque la analitica es bastante valorada en el mercado laboral Considero realmente interesante aprender nuevas herramientas que me permitan mejorar a nivel profesional Me gusta mucho el analisis de datos, en especial las predicciones y analisis de texto que permitan una correcta visualizacion y que le dé valor al cliente Por las aplicaciones que hoy en día tiene en la industria. para tener un crecimiento personal y laboral Quiero dedicarme a esto el resto de mi vida y todos estos temas me sirven para poder ir alcanzando mi sueno Creo que los datos son y seran cada vez mas importantes, asi que aprender a manipularlos puede ser muy util para mi vida Me gusta la analítica de datos y el valor que aporta actualmente en la industria Me parece que la tecn ...

# %%
cadena = cadena.split() # Separamos por palabra 

cadena
# Out:
# ['Me',
#  'gustan',
#  'mucho',
#  'las',
#  'matemáticas,',
#  'la',
#  'programación',
#  'y',
#  'la',
#  'comunicación.',
#  'Pienso',
#  'que',
#  'la',
#  'ciencia',
#  'de',
#  'datos',
#  'es',
#  'una',
#  'buena',
#  'mezcla',
#  'entre',
#  'esas',
#  'tres',
#  'áreas.',
#  'Desarrollo',
#  'profesional',
#  'y',
#  'proyecto',
#  'personal.',
#  'Muchas',
#  'de',
#  'las',
#  'decisiones',
#  'se',
#  'basan',
#  'en',
#  'datos',
#  'y',
#  'creo',
#  'que',
#  'nos',
#  'aportan',
#  'mucho',
#  'tanto',
#  'en',
#  'lo',
#  'personal',
#  'como',
#  'en',
#  'lo',
#  'profesional',
#  'Trabajo',
#  'con',
#  'temas',
#  'relacionados',
#  'a',
#  'gestión',
#  'de',
#  'información',
#  'y',
#  'estoy',
#  'interesado',
#  'en',
#  'aprender',
#  'a',
#  'utilizar',
#  'herramientas',
#  'que',
#  'faciliten',
#  'la',
#  'toma',
#  'de',
#  'decisiones',
#  'en',
#  'mi',
#  'lugar',
#  'de',
#  'trabajo.',
#  'En',
#  'mi',
#  'experiencia',
#  'en',
#  'investigación',
#  'de',
#  'mercados',
#  'y',
#  'mercadeo',
#  'empecé',
#  'a',
#  'descubrir',
#  'el',
#  'mundo',
#  'de',
#  'la',
#  'analítica',
#  'y',
#  'me',
#  'apasiona',
#  'saber',
#  'que',
#  'podemos',
#  'usar',
#  'los',
#  'avances',
#  'tecnológicos',
#  'y',
#  'la',
#  'gran',
#  'cantidad',
#  'de',
#  'datos',
#  'que',
#  'hay,',
#  'para',
#  'entender',
#  'mejor',
#  'a',
#  'los',
#  'clientes',
#  'y',
#  'desarrollar',
#  'proyectos',
#  'que',
#  'ayuden',
#  'a',
#  'facilitar',
#  'los',
#  'procesos',
#  'en',
#  'las',
#  'organizaciones,',
#  'además',
#  'es',
#  'útil',
#  'en',
#  'mi',
#  'trabajo',
#  'como',
#  'analista',
#  'de',
#  'investigación',
#  'digital',
#  'Me',
#  'gustan',
#  'mucho',
#  'los',
#  'datos',
#  'y',
#  'quiero',
#  'aprenden',
#  'como',
#  'aprovecharlos',
#  'al',
#  'maximo',
#  'Me',
#  'encuentro',
#  'interesado',
#  'en',
#  'aprender',
#  'diferentes',
#  'métodos,',
#  'metodologías,',
#  'lenguajes',
#  'y',
#  'demás',
#  'para',
#  'convertirme',
#  'en',
#  'un',
#  'Científico',
#  'de',
#  'Datos',
#  'En',
#  'mi',
#  'carrera',
#  'profesional',
#  'es',
#  'muy',
#  'útil',
#  'y',
#  'porque',
#  'el',
#  'manejo',
#  'de',
#  'la',
#  'información',
#  'día',
#  'a',
#  'día',
#  'genera',
#  'mucho',
#  'interes',
#  'y',
#  'mucho',
#  'valor',
#  'en',
#  'todo.',
#  'Quiero',
#  'aprender',
#  'mucho',
#  'de',
#  'herramientas',
#  'y',
#  'temas',
#  'al',
#  'respecto.',
#  'Quiero',
#  'crear',
#  'productos',
#  'digitales',
#  'de',
#  'alto',
#  'impacto,',
#  'que',
#  'solucionen',
#  'problemas',
#  'y',
#  'sean',
#  'rentables.',
#  'Me',
#  'gusta',
#  'programar',
#  'en',
#  'python',
#  'Porder',
#  'aplicar',
#  'mis',
#  'conocimientos',
#  'a',
#  'mi',
#  'labor',
#  'profesional',
#  'en',
#  'analitica',
#  'web',
#  ',',
#  'creando',
#  'modelos',
#  'de',
#  'recomendación',
#  'y',
#  'personalizacion',
#  'para',
#  'las',
#  'paginas',
#  'web',
#  '(contenidos',
#  '-',
#  'ecommerce',
#  '-',
#  'apps)',
#  'Trabajo',
#  'con',
#  'altos',
#  'volúmenes',
#  'de',
#  'información',
#  'estructurada',
#  'y',
#  'no',
#  'estructurada',
#  'con',
#  'lo',
#  'que',
#  'mi',
#  'interés',
#  'es',
#  'generar',
#  'valor',
#  'a',
#  'la',
#  'compañía',
#  'y',
#  'a',
#  'los',
#  'sectores',
#  'de',
#  'interes',
#  'usando',
#  'herramientas',
#  'de',
#  'analitica',
#  'para',
#  'procesar',
#  'información',
#  'de',
#  'clientes,',
#  'ventas,',
#  'procesos',
#  'de',
#  'reclamación,',
#  'quejas,',
#  'contactos',
#  'con',
#  'bots',
#  'entre',
#  'otros.',
#  'Ademas',
#  'veo',
#  'que',
#  'es',
#  'un',
#  'complemento',
#  'interesante',
#  'con',
#  'otras',
#  'áreas',
#  'de',
#  'trabajo',
#  'entre',
#  'las',
#  'técnicas',
#  'y',
#  'humanas.',
#  'Implementar',
#  'métodos',
#  'de',
#  'estudio',
#  'de',
#  'machine',
#  'learning',
#  'a',
#  'las',
#  'ciencias',
#  'sociales',
#  'Estamos',
#  'en',
#  'contacto',
#  'permanente',
#  'con',
#  'los',
#  'datos',
#  'y',
#  'me',
#  'gusta',
#  'saber',
#  'cómo',
#  'hay',
#  'una',
#  'interacción',
#  'entre',
#  'ellos',
#  'y',
#  'cómo',
#  'pueden',
#  'tomarse',
#  'decisiones',
#  'basados',
#  'en',
#  'estos.',
#  'Aprender',
#  'y',
#  'sacar',
#  'el',
#  'mejor',
#  'provecho',
#  'a',
#  'los',
#  'conocimientos',
#  'adquiridos',
#  'Quiero',
#  'aprender',
#  'a',
#  'sacarle',
#  'provecho',
#  'a',
#  'los',
#  'datos',
#  'y',
#  'darles',
#  'un',
#  'valor',
#  'en',
#  'mi',
#  'vida',
#  'profesional',
#  'y',
#  'personal',
#  'Aprender',
#  'nuevas',
#  'herramientas',
#  'y',
#  'saber',
#  'como',
#  'analizar',
#  'los',
#  'datos',
#  'para',
#  'la',
#  'toma',
#  'de',
#  'decisiones',
#  'Generar',
#  'nuevos',
#  'conocimientos',
#  'en',
#  'herramientas',
#  'de',
#  'analitica',
#  'que',
#  'me',
#  'aporten',
#  'para',
#  'el',
#  'analisis',
#  'de',
#  'la',
#  'información',
#  'y',
#  'en',
#  'toma',
#  'de',
#  'decisiones',
#  '.',
#  'Por',
#  'la',
#  'gran',
#  'cantidad',
#  'de',
#  'datos',
#  'que',
#  'se',
#  'maneja',
#  'en',
#  'mi',
#  'ámbito',
#  'laboral,',
#  'y',
#  'por',
#  'el',
#  'reto',
#  'personal',
#  'que',
#  'para',
#  'mi',
#  'refleja',
#  'manejar',
#  'esos',
#  'datos',
#  'El',
#  'mundo',
#  'actual',
#  'cuenta',
#  'con',
#  'grandes',
#  'volumenes',
#  'de',
#  'datos,',
#  'pero',
#  'ahora',
#  'es',
#  'tiempo',
#  'de',
#  'analizar',
#  'y',
#  'comprender',
#  'las',
#  'necesidades',
#  'de',
#  'cada',
#  'sector.',
#  'Mi',
#  'interés',
#  'en',
#  'la',
#  'especialización',
#  'es',
#  'tener',
#  'un',
#  'conocimiento',
#  'más',
#  'amplio,',
#  'enfocado',
#  'y',
#  'profesional',
#  'para',
#  'la',
#  'manipulación',
#  'de',
#  'datos,',
#  'abarcando',
#  'desde',
#  'la',
#  'recolección,',
#  'procesamiento,',
#  'análisis',
#  'e',
#  'interpretación',
#  'para',
#  'el',
#  'usuario',
#  'final',
#  'cuyo',
#  'un',
#  'objetivo',
#  'fundamental',
#  'es',
#  'generar',
#  'valor',
#  'agregado',
#  'en',
#  'mis',
#  'reportes',
#  'para',
#  'una',
#  'óptima',
#  'toma',
#  'de',
#  'decisiones',
#  'que',
#  'beneficien',
#  'cualquier',
#  'plan',
#  'estratégico',
#  'en',
#  'las',
#  'empresas',
#  'Por',
#  'complemento',
#  'profesional,',
#  'porque',
#  'la',
#  'analitica',
#  'es',
#  'bastante',
#  'valorada',
#  'en',
#  'el',
#  'mercado',
#  'laboral',
#  'Considero',
#  'realmente',
#  'interesante',
#  'aprender',
#  'nuevas',
#  'herramientas',
#  'que',
#  'me',
#  'permitan',
#  'mejorar',
#  'a',
#  'nivel',
#  'profesional',
#  'Me',
#  'gusta',
#  'mucho',
#  'el',
#  'analisis',
#  'de',
#  'datos,',
#  'en',
#  'especial',
#  'las',
#  'predicciones',
#  'y',
#  'analisis',
#  'de',
#  'texto',
#  'que',
#  'permitan',
#  'una',
#  'correcta',
#  'visualizacion',
#  'y',
#  'que',
#  'le',
#  'dé',
#  'valor',
#  'al',
#  'cliente',
#  'Por',
#  'las',
#  'aplicaciones',
#  'que',
#  'hoy',
#  'en',
#  'día',
#  'tiene',
#  'en',
#  'la',
#  'industria.',
#  'para',
#  'tener',
#  'un',
#  'crecimiento',
#  'personal',
#  'y',
#  'laboral',
#  'Quiero',
#  'dedicarme',
#  'a',
#  'esto',
#  'el',
#  'resto',
#  'de',
#  'mi',
#  'vida',
#  'y',
#  'todos',
#  'estos',
#  'temas',
#  'me',
#  'sirven',
#  'para',
#  'poder',
#  'ir',
#  'alcanzando',
#  'mi',
#  'sueno',
#  'Creo',
#  'que',
#  'los',
#  'datos',
#  'son',
#  'y',
#  'seran',
#  'cada',
#  'vez',
#  'mas',
#  'importantes,',
#  'asi',
#  'que',
#  'aprender',
#  'a',
#  'manipularlos',
#  'puede',
#  'ser',
#  'muy',
#  'util',
#  'para',
#  'mi',
#  'vida',
#  'Me',
#  'gusta',
#  'la',
#  'analítica',
#  'de',
#  'datos',
#  'y',
#  'el',
#  'valor',
#  'que',
#  'aporta',
#  'actualmente',
#  'en',
#  'la',
#  'industria',
#  'Me',
#  'parece',
#  'que',
#  'la',
#  'tecnología',
#  'es',
#  'lo',
#  'que',
#  'rige',
#  'el',
#  'mundo',
#  'actual',
#  'y',
#  'aprender',
#  'un',
#  'poco',
#  'del',
#  'comportamiento',
#  'de',
#  'las',
#  'personas',
#  'a',
#  'traves',
#  'de',
#  'los',
#  'datos',
#  'es',
#  'muy',
#  'interesante',
#  'Aprender',
#  'de',
#  'nuevas',
#  'herramientas',
#  'para',
#  'el',
#  'análisis',
#  'y',
#  'procesamiento',
#  'de',
#  'datos',
#  'Creo',
#  'que',
#  'es',
#  'el',
#  'futuro,',
#  'me',
#  'gusta',
#  'y',
#  'de',
#  'cerca',
#  'he',
#  'visto',
#  'el',
#  'impacto',
#  'positivo',
#  'que',
#  'genera',
#  'en',
#  'una',
#  'organización']

# %%
from collections import Counter

Counter(cadena)
# Out:
# Counter({'Me': 7,
#          'gustan': 2,
#          'mucho': 7,
#          'las': 11,
#          'matemáticas,': 1,
#          'la': 19,
#          'programación': 1,
#          'y': 37,
#          'comunicación.': 1,
#          'Pienso': 1,
#          'que': 24,
#          'ciencia': 1,
#          'de': 41,
#          'datos': 13,
#          'es': 12,
#          'una': 5,
#          'buena': 1,
#          'mezcla': 1,
#          'entre': 4,
#          'esas': 1,
#          'tres': 1,
#          'áreas.': 1,
#          'Desarrollo': 1,
#          'profesional': 7,
#          'proyecto': 1,
#          'personal.': 1,
#          'Muchas': 1,
#          'decisiones': 6,
#          'se': 2,
#          'basan': 1,
#          'en': 28,
#          'creo': 1,
#          'nos': 1,
#          'aportan': 1,
#          'tanto': 1,
#          'lo': 4,
#          'personal': 4,
#          'como': 4,
#          'Trabajo': 2,
#          'con': 7,
#          'temas': 3,
#          'relacionados': 1,
#          'a': 17,
#          'gestión': 1,
#          'información': 5,
#          'estoy': 1,
#          'interesado': 2,
#          'aprender': 7,
#          'utilizar': 1,
#          'herramientas': 7,
#          'faciliten': 1,
#          'toma': 4,
#          'mi': 12,
#          'lugar': 1,
#          'trabajo.': 1,
#          'En': 2,
#          'experiencia': 1,
#          'investigación': 2,
#          'mercados': 1,
#          'mercadeo': 1,
#          'empecé': 1,
#          'descubrir': 1,
#          'el': 14,
#          'mundo': 3,
#          'analítica': 2,
#          'me': 6,
#          'apasiona': 1,
#          'saber': 3,
#          'podemos': 1,
#          'usar': 1,
#          'los': 11,
#          'avances': 1,
#          'tecnológicos': 1,
#          'gran': 2,
#          'cantidad': 2,
#          'hay,': 1,
#          'para': 14,
#          'entender': 1,
#          'mejor': 2,
#          'clientes': 1,
#          'desarrollar': 1,
#          'proyectos': 1,
#          'ayuden': 1,
#          'facilitar': 1,
#          'procesos': 2,
#          'organizaciones,': 1,
#          'además': 1,
#          'útil': 2,
#          'trabajo': 2,
#          'analista': 1,
#          'digital': 1,
#          'quiero': 1,
#          'aprenden': 1,
#          'aprovecharlos': 1,
#          'al': 3,
#          'maximo': 1,
#          'encuentro': 1,
#          'diferentes': 1,
#          'métodos,': 1,
#          'metodologías,': 1,
#          'lenguajes': 1,
#          'demás': 1,
#          'convertirme': 1,
#          'un': 7,
#          'Científico': 1,
#          'Datos': 1,
#          'carrera': 1,
#          'muy': 3,
#          'porque': 2,
#          'manejo': 1,
#          'día': 3,
#          'genera': 2,
#          'interes': 2,
#          'valor': 6,
#          'todo.': 1,
#          'Quiero': 4,
#          'respecto.': 1,
#          'crear': 1,
#          'productos': 1,
#          'digitales': 1,
#          'alto': 1,
#          'impacto,': 1,
#          'solucionen': 1,
#          'problemas': 1,
#          'sean': 1,
#          'rentables.': 1,
#          'gusta': 5,
#          'programar': 1,
#          'python': 1,
#          'Porder': 1,
#          'aplicar': 1,
#          'mis': 2,
#          'conocimientos': 3,
#          'labor': 1,
#          'analitica': 4,
#          'web': 2,
#          ',': 1,
#          'creando': 1,
#          'modelos': 1,
#          'recomendación': 1,
#          'personalizacion': 1,
#          'paginas': 1,
#          '(contenidos': 1,
#          '-': 2,
#          'ecommerce': 1,
#          'apps)': 1,
#          'altos': 1,
#          'volúmenes': 1,
#          'estructurada': 2,
#          'no': 1,
#          'interés': 2,
#          'generar': 2,
#          'compañía': 1,
#          'sectores': 1,
#          'usando': 1,
#          'procesar': 1,
#          'clientes,': 1,
#          'ventas,': 1,
#          'reclamación,': 1,
#          'quejas,': 1,
#          'contactos': 1,
#          'bots': 1,
#          'otros.': 1,
#          'Ademas': 1,
#          'veo': 1,
#          'complemento': 2,
#          'interesante': 3,
#          'otras': 1,
#          'áreas': 1,
#          'técnicas': 1,
#          'humanas.': 1,
#          'Implementar': 1,
#          'métodos': 1,
#          'estudio': 1,
#          'machine': 1,
#          'learning': 1,
#          'ciencias': 1,
#          'sociales': 1,
#          'Estamos': 1,
#          'contacto': 1,
#          'permanente': 1,
#          'cómo': 2,
#          'hay': 1,
#          'interacción': 1,
#          'ellos': 1,
#          'pueden': 1,
#          'tomarse': 1,
#          'basados': 1,
#          'estos.': 1,
#          'Aprender': 3,
#          'sacar': 1,
#          'provecho': 2,
#          'adquiridos': 1,
#          'sacarle': 1,
#          'darles': 1,
#          'vida': 3,
#          'nuevas': 3,
#          'analizar': 2,
#          'Generar': 1,
#          'nuevos': 1,
#          'aporten': 1,
#          'analisis': 3,
#          '.': 1,
#          'Por': 3,
#          'maneja': 1,
#          'ámbito': 1,
#          'laboral,': 1,
#          'por': 1,
#          'reto': 1,
#          'refleja': 1,
#          'manejar': 1,
#          'esos': 1,
#          'El': 1,
#          'actual': 2,
#          'cuenta': 1,
#          'grandes': 1,
#          'volumenes': 1,
#          'datos,': 3,
#          'pero': 1,
#          'ahora': 1,
#          'tiempo': 1,
#          'comprender': 1,
#          'necesidades': 1,
#          'cada': 2,
#          'sector.': 1,
#          'Mi': 1,
#          'especialización': 1,
#          'tener': 2,
#          'conocimiento': 1,
#          'más': 1,
#          'amplio,': 1,
#          'enfocado': 1,
#          'manipulación': 1,
#          'abarcando': 1,
#          'desde': 1,
#          'recolección,': 1,
#          'procesamiento,': 1,
#          'análisis': 2,
#          'e': 1,
#          'interpretación': 1,
#          'usuario': 1,
#          'final': 1,
#          'cuyo': 1,
#          'objetivo': 1,
#          'fundamental': 1,
#          'agregado': 1,
#          'reportes': 1,
#          'óptima': 1,
#          'beneficien': 1,
#          'cualquier': 1,
#          'plan': 1,
#          'estratégico': 1,
#          'empresas': 1,
#          'profesional,': 1,
#          'bastante': 1,
#          'valorada': 1,
#          'mercado': 1,
#          'laboral': 2,
#          'Considero': 1,
#          'realmente': 1,
#          'permitan': 2,
#          'mejorar': 1,
#          'nivel': 1,
#          'especial': 1,
#          'predicciones': 1,
#          'texto': 1,
#          'correcta': 1,
#          'visualizacion': 1,
#          'le': 1,
#          'dé': 1,
#          'cliente': 1,
#          'aplicaciones': 1,
#          'hoy': 1,
#          'tiene': 1,
#          'industria.': 1,
#          'crecimiento': 1,
#          'dedicarme': 1,
#          'esto': 1,
#          'resto': 1,
#          'todos': 1,
#          'estos': 1,
#          'sirven': 1,
#          'poder': 1,
#          'ir': 1,
#          'alcanzando': 1,
#          'sueno': 1,
#          'Creo': 2,
#          'son': 1,
#          'seran': 1,
#          'vez': 1,
#          'mas': 1,
#          'importantes,': 1,
#          'asi': 1,
#          'manipularlos': 1,
#          'puede': 1,
#          'ser': 1,
#          'util': 1,
#          'aporta': 1,
#          'actualmente': 1,
#          'industria': 1,
#          'parece': 1,
#          'tecnología': 1,
#          'rige': 1,
#          'poco': 1,
#          'del': 1,
#          'comportamiento': 1,
#          'personas': 1,
#          'traves': 1,
#          'procesamiento': 1,
#          'futuro,': 1,
#          'cerca': 1,
#          'he': 1,
#          'visto': 1,
#          'impacto': 1,
#          'positivo': 1,
#          'organización': 1})

# %% [markdown]
# Para verlo ordenado

# %%
Counter(cadena).most_common()
# Out:
# [('de', 41),
#  ('y', 37),
#  ('en', 28),
#  ('que', 24),
#  ('la', 19),
#  ('a', 17),
#  ('el', 14),
#  ('para', 14),
#  ('datos', 13),
#  ('es', 12),
#  ('mi', 12),
#  ('las', 11),
#  ('los', 11),
#  ('Me', 7),
#  ('mucho', 7),
#  ('profesional', 7),
#  ('con', 7),
#  ('aprender', 7),
#  ('herramientas', 7),
#  ('un', 7),
#  ('decisiones', 6),
#  ('me', 6),
#  ('valor', 6),
#  ('una', 5),
#  ('información', 5),
#  ('gusta', 5),
#  ('entre', 4),
#  ('lo', 4),
#  ('personal', 4),
#  ('como', 4),
#  ('toma', 4),
#  ('Quiero', 4),
#  ('analitica', 4),
#  ('temas', 3),
#  ('mundo', 3),
#  ('saber', 3),
#  ('al', 3),
#  ('muy', 3),
#  ('día', 3),
#  ('conocimientos', 3),
#  ('interesante', 3),
#  ('Aprender', 3),
#  ('vida', 3),
#  ('nuevas', 3),
#  ('analisis', 3),
#  ('Por', 3),
#  ('datos,', 3),
#  ('gustan', 2),
#  ('se', 2),
#  ('Trabajo', 2),
#  ('interesado', 2),
#  ('En', 2),
#  ('investigación', 2),
#  ('analítica', 2),
#  ('gran', 2),
#  ('cantidad', 2),
#  ('mejor', 2),
#  ('procesos', 2),
#  ('útil', 2),
#  ('trabajo', 2),
#  ('porque', 2),
#  ('genera', 2),
#  ('interes', 2),
#  ('mis', 2),
#  ('web', 2),
#  ('-', 2),
#  ('estructurada', 2),
#  ('interés', 2),
#  ('generar', 2),
#  ('complemento', 2),
#  ('cómo', 2),
#  ('provecho', 2),
#  ('analizar', 2),
#  ('actual', 2),
#  ('cada', 2),
#  ('tener', 2),
#  ('análisis', 2),
#  ('laboral', 2),
#  ('permitan', 2),
#  ('Creo', 2),
#  ('matemáticas,', 1),
#  ('programación', 1),
#  ('comunicación.', 1),
#  ('Pienso', 1),
#  ('ciencia', 1),
#  ('buena', 1),
#  ('mezcla', 1),
#  ('esas', 1),
#  ('tres', 1),
#  ('áreas.', 1),
#  ('Desarrollo', 1),
#  ('proyecto', 1),
#  ('personal.', 1),
#  ('Muchas', 1),
#  ('basan', 1),
#  ('creo', 1),
#  ('nos', 1),
#  ('aportan', 1),
#  ('tanto', 1),
#  ('relacionados', 1),
#  ('gestión', 1),
#  ('estoy', 1),
#  ('utilizar', 1),
#  ('faciliten', 1),
#  ('lugar', 1),
#  ('trabajo.', 1),
#  ('experiencia', 1),
#  ('mercados', 1),
#  ('mercadeo', 1),
#  ('empecé', 1),
#  ('descubrir', 1),
#  ('apasiona', 1),
#  ('podemos', 1),
#  ('usar', 1),
#  ('avances', 1),
#  ('tecnológicos', 1),
#  ('hay,', 1),
#  ('entender', 1),
#  ('clientes', 1),
#  ('desarrollar', 1),
#  ('proyectos', 1),
#  ('ayuden', 1),
#  ('facilitar', 1),
#  ('organizaciones,', 1),
#  ('además', 1),
#  ('analista', 1),
#  ('digital', 1),
#  ('quiero', 1),
#  ('aprenden', 1),
#  ('aprovecharlos', 1),
#  ('maximo', 1),
#  ('encuentro', 1),
#  ('diferentes', 1),
#  ('métodos,', 1),
#  ('metodologías,', 1),
#  ('lenguajes', 1),
#  ('demás', 1),
#  ('convertirme', 1),
#  ('Científico', 1),
#  ('Datos', 1),
#  ('carrera', 1),
#  ('manejo', 1),
#  ('todo.', 1),
#  ('respecto.', 1),
#  ('crear', 1),
#  ('productos', 1),
#  ('digitales', 1),
#  ('alto', 1),
#  ('impacto,', 1),
#  ('solucionen', 1),
#  ('problemas', 1),
#  ('sean', 1),
#  ('rentables.', 1),
#  ('programar', 1),
#  ('python', 1),
#  ('Porder', 1),
#  ('aplicar', 1),
#  ('labor', 1),
#  (',', 1),
#  ('creando', 1),
#  ('modelos', 1),
#  ('recomendación', 1),
#  ('personalizacion', 1),
#  ('paginas', 1),
#  ('(contenidos', 1),
#  ('ecommerce', 1),
#  ('apps)', 1),
#  ('altos', 1),
#  ('volúmenes', 1),
#  ('no', 1),
#  ('compañía', 1),
#  ('sectores', 1),
#  ('usando', 1),
#  ('procesar', 1),
#  ('clientes,', 1),
#  ('ventas,', 1),
#  ('reclamación,', 1),
#  ('quejas,', 1),
#  ('contactos', 1),
#  ('bots', 1),
#  ('otros.', 1),
#  ('Ademas', 1),
#  ('veo', 1),
#  ('otras', 1),
#  ('áreas', 1),
#  ('técnicas', 1),
#  ('humanas.', 1),
#  ('Implementar', 1),
#  ('métodos', 1),
#  ('estudio', 1),
#  ('machine', 1),
#  ('learning', 1),
#  ('ciencias', 1),
#  ('sociales', 1),
#  ('Estamos', 1),
#  ('contacto', 1),
#  ('permanente', 1),
#  ('hay', 1),
#  ('interacción', 1),
#  ('ellos', 1),
#  ('pueden', 1),
#  ('tomarse', 1),
#  ('basados', 1),
#  ('estos.', 1),
#  ('sacar', 1),
#  ('adquiridos', 1),
#  ('sacarle', 1),
#  ('darles', 1),
#  ('Generar', 1),
#  ('nuevos', 1),
#  ('aporten', 1),
#  ('.', 1),
#  ('maneja', 1),
#  ('ámbito', 1),
#  ('laboral,', 1),
#  ('por', 1),
#  ('reto', 1),
#  ('refleja', 1),
#  ('manejar', 1),
#  ('esos', 1),
#  ('El', 1),
#  ('cuenta', 1),
#  ('grandes', 1),
#  ('volumenes', 1),
#  ('pero', 1),
#  ('ahora', 1),
#  ('tiempo', 1),
#  ('comprender', 1),
#  ('necesidades', 1),
#  ('sector.', 1),
#  ('Mi', 1),
#  ('especialización', 1),
#  ('conocimiento', 1),
#  ('más', 1),
#  ('amplio,', 1),
#  ('enfocado', 1),
#  ('manipulación', 1),
#  ('abarcando', 1),
#  ('desde', 1),
#  ('recolección,', 1),
#  ('procesamiento,', 1),
#  ('e', 1),
#  ('interpretación', 1),
#  ('usuario', 1),
#  ('final', 1),
#  ('cuyo', 1),
#  ('objetivo', 1),
#  ('fundamental', 1),
#  ('agregado', 1),
#  ('reportes', 1),
#  ('óptima', 1),
#  ('beneficien', 1),
#  ('cualquier', 1),
#  ('plan', 1),
#  ('estratégico', 1),
#  ('empresas', 1),
#  ('profesional,', 1),
#  ('bastante', 1),
#  ('valorada', 1),
#  ('mercado', 1),
#  ('Considero', 1),
#  ('realmente', 1),
#  ('mejorar', 1),
#  ('nivel', 1),
#  ('especial', 1),
#  ('predicciones', 1),
#  ('texto', 1),
#  ('correcta', 1),
#  ('visualizacion', 1),
#  ('le', 1),
#  ('dé', 1),
#  ('cliente', 1),
#  ('aplicaciones', 1),
#  ('hoy', 1),
#  ('tiene', 1),
#  ('industria.', 1),
#  ('crecimiento', 1),
#  ('dedicarme', 1),
#  ('esto', 1),
#  ('resto', 1),
#  ('todos', 1),
#  ('estos', 1),
#  ('sirven', 1),
#  ('poder', 1),
#  ('ir', 1),
#  ('alcanzando', 1),
#  ('sueno', 1),
#  ('son', 1),
#  ('seran', 1),
#  ('vez', 1),
#  ('mas', 1),
#  ('importantes,', 1),
#  ('asi', 1),
#  ('manipularlos', 1),
#  ('puede', 1),
#  ('ser', 1),
#  ('util', 1),
#  ('aporta', 1),
#  ('actualmente', 1),
#  ('industria', 1),
#  ('parece', 1),
#  ('tecnología', 1),
#  ('rige', 1),
#  ('poco', 1),
#  ('del', 1),
#  ('comportamiento', 1),
#  ('personas', 1),
#  ('traves', 1),
#  ('procesamiento', 1),
#  ('futuro,', 1),
#  ('cerca', 1),
#  ('he', 1),
#  ('visto', 1),
#  ('impacto', 1),
#  ('positivo', 1),
#  ('organización', 1)]

# %% [markdown]
# #### ¿Mayúsculas? ¿Tíldes? ¿Palabras muy frecuentes? ¿Cómo lo visualizamos?
#
# ... En el próximo capítulo de NLP

# %% [markdown]
# # Subir a GitHub, enviar link al aula virtual
